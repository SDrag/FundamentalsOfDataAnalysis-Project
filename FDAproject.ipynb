# %% [markdown]
# # Box Plot

# %% [markdown]
# Box Plot is a method for graphically depicting groups of numerical data through their quartiles (fourths). Box plots may also have lines extending vertically from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot and box-and-whisker diagram.
#
# The box plot allows quick graphical examination of one or more data sets and gives us a good indication of how the values in the data are spread out.
#
# They take up less space and are therefore particularly useful for comparing distributions between several groups or sets of data.

# %% [markdown]
# ## Summarising the history of the box plot and situations in which it is used

# %% [markdown]
# Box plots were invented by John Tukey in 1970, but it wasn't until his publication in 1977, "Exploratory Data Analysis", that they became widely known.
#
# Boxplots use robust summary statistics that are always located at actual data points, are quickly
# computable (originally by hand), and have no tuning parameters. They are particularly useful for comparing
# distributions across groups.
#
# Today, over 40 years later, the boxplot has become one of the most frequently used statistical graphics,
# and is one of the few plot types invented in the 20th century that has found widespread adoption.
#
# Box plots are good for comparison because the distribution is immediately clear. It is often used in explanatory data analysis. They are useful when categorial data is available. Categorical variables represent types of data which may be divided into groups.
#
# Box plots are made up of five components:
#
# • the median,
# • two hinges, the upper and lower fourths (quartiles),
# • the data values adjacent to the upper and lower fences, which lie 1.5 times the inter-fourth range from the median,
# • two whiskers that connect the hinges to the fences, and
# • (potential) out-liers, individual points further away from the median than the extremes.
#
# A Box Plot example:

# %%
# import libraries for the code in the notebook
import pandas as pd
import seaborn as sns
import matplotlib as mpl 
import matplotlib.pyplot as plt
import numpy as np
import calendar

# %matplotlib inline

# some data to plot:
data = [55, 10, 25, 36, 17, 5, 41, 52, 43, 27, 61, 8, 44, 11, 110, 153, 77]

# create box plot
bp = sns.boxplot(x=data)

# add title
bp.set_title('Box Plot Example',fontsize=18)
bp

# %% [markdown]
# ## Demonstrating the use of the box plot

# %% [markdown]
# For the demonstration of Box Plot usage I selected a data set from Met Éireann Valentia Observatory located on data.gove.ie (https://data.gov.ie/dataset/valentia-observatory-monthly-data/resource/16b3b81c-1ffe-4b2d-8495-50b1fcf4fa80).
#
# "The dataset contains monthly elements measured at our synoptic station in Valentia Observatory, Co Kerry.
# Values for each month include: Precipitation Amount, Mean Air Temperature, Maximum Air Temperature (C), Minimum Air Temperature, Mean Maximum Temperature, Mean Minimum Temperature, Grass Minimum Temperature, Mean Wind Speed, Highest Gust, Sunshine duration."

# %%
# read the data from csv file
df = pd.read_csv("data/mly2275.csv")

# show first 5 rows
df.head(5)
# Out:
#    year  month  meant  maxtp  mintp  mnmax  mnmin   rain  gmin  wdsp maxgt  \
# 0  1939     10   10.0   16.8    0.0   13.2    6.7  105.5  -4.4   9.9    55
# 1  1939     11   10.3   14.0    4.0   12.4    8.1  251.9   0.5  13.9    60
# 2  1939     12    6.0   13.6   -3.3    8.7    3.3  116.9  -7.8  10.6    59
# 3  1940      1    5.8   12.3   -5.6    8.4    3.3  163.8  -8.4  11.6    51
# 4  1940      2    7.9   12.8   -3.9   10.1    5.7  179.6  -5.8  13.0    55
#
#      sun
# 0  140.0
# 1   36.4
# 2   65.8
# 3   76.3
# 4   67.2

# %%
# set plot size
fig, ax = plt.subplots(figsize=(10,10))

# set plot structure
bp = sns.boxplot(y='rain', x='month',
                 data=df, 
                 width=0.5,
                 palette="colorblind")

bp.set_title('Monthly Rainfall' ,fontsize=20)
bp.set_ylabel('Rainfall',fontsize=18)
bp.set_xlabel('Month', fontsize=18)

plt.show()

# %% [markdown]
# From the boxplot above, we can conclude that the most rainy months are Oct-Jan and months with the least rainfall are Jun-July.
# Most skewness are in March and May. In general, data is not much skewed, which means that the distribution is almost normal.
# Also, there are not much outliers - there are none for half of the months.

# %% [markdown]
# ## Explaining relevant terminology such as the terms quartile and percentile

# %% [markdown]
# #### Median
# The median (middle quartile) marks the mid-point of the data and is shown by the line that divides the box into two parts. Half the scores are greater than or equal to this value and half are less.
#
# #### Inter-quartile range
# The middle “box” represents the middle 50% of scores for the group. The range of scores from lower to upper quartile is referred to as the inter-quartile range. The middle 50% of scores fall within the inter-quartile range.
#
# #### Upper quartile
# Seventy-five percent of the scores fall below the upper quartile.
#
# #### Lower quartile
# Twenty-five percent of scores fall below the lower quartile.
#
# #### Whiskers
# The upper and lower whiskers represent scores outside the middle 50%. Whiskers often (but not always) stretch over a wider range of scores than the middle quartile groups.
#
# #### Outlier
# Outliers beyond whiskers represent the extremes. They are usually treated as abnormal values usually representing very high or very low values. In a Tukey box plot values outside 1.5 times the inter-quartile from the first or third quartile would be considered as outliers and displayed as simple points.

# %% [markdown]
# ## Box Plot to alternatives

# %% [markdown]
# Some alternatives to the boxplot:
#
# - Histogram
# - The Violin Plot
# - Notched Box Plot
# - Boxenplot
#
# ### Histogram
#
# A histogram is a graphical representation of a frequency distribution for numeric data. It is a bar chart that is often used as the first step to determine the probability distribution of a data set or a sample. It allows to visually and quickly assess the shape of the distribution, the central tendency, the amount of variation in the data, and the presence of gaps, outliers or unusual data points.

# %%
fig, ax = plt.subplots(figsize=(10,5))

# segment dataset
for i in range(1, 13):
    x = df[df['month'] == i]
    plot = sns.distplot(x['rain'], label=calendar.month_name[i], ax=ax)

# customise graph
ax.text(x=0.5, y=1.03, s='Monthly Rainfall', fontsize=26,  ha='center', va='bottom', transform=ax.transAxes) 
plt.legend()
plt.show()

# %% [markdown]
# ### The Violin Plot
#
# The Violin plot is closely related to Tukey's boxplot. The violin plot combines the box plot with a kernel density estimation (KDE) of the underlying distribution. This can be useful if you want to visualize just the “shape” of some data.
#
# A Violin plot is more informative than a plain box plot as it shows the full distribution of data.

# %%
fig.set_size_inches((10,10))

# plot violinpolt
plot = sns.violinplot(x='month', y ='rain', data=df)

# customise plot
plot.set_title('Monthly Rainfall',fontsize=20)
plot.set_ylabel('Rainfall (mm)',fontsize=20)
plot.set_xlabel('Month',fontsize=20)

#show plot
plt.show()

# %% [markdown]
# ### Notched Box Plot
#
# Another alternative to the box plot is the notched box plot which works the same as the Box Plot but has a narrowing of the box around the median value.
#
# This can be very helpful when comparing the differences across data series.

# %%
fig, ax = plt.subplots(figsize=(10,10))

# set plot structure
bp = sns.boxplot(y='rain', x='month',
                 data=df, 
                 width=0.5,
                 notch='true')

bp.set_title('Monthly Rainfall' ,fontsize=20)
bp.set_ylabel('Rainfall',fontsize=18)
bp.set_xlabel('Month', fontsize=18)

plt.show()

# %% [markdown]
# ### Boxenplot
#
# Also known as letter-value boxplot. The simple boxplot
# is not a good method for large datasets, since there is often too much over-plotting in the outlier region. To
# overcome this problem, Hofmann, Kafadar, and Wickham (2006) introduced the Letter-Value boxplot.

# %%
fig.set_size_inches((10,10))

#plot boxenplot
plot = sns.boxenplot(x='month', y ='rain', data=df)

plot.set_title('Monthly Rainfall',fontsize=20)
plot.set_ylabel('Rainfall (mm)',fontsize=18)
plot.set_xlabel('Month',fontsize=18)

plt.show()

# %% [markdown]
# ## References

# %% [markdown]
# https://en.wikipedia.org/wiki/Box_plot
#
# https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
#
# https://chartio.com/resources/tutorials/what-is-a-box-plot/
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
# https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/box-whisker-plots/a/box-plot-review
#
# https://stats.stackexchange.com/questions/369393/whats-the-history-of-box-plots-and-how-did-the-box-and-whiskers-design-evolv
#
# http://vita.had.co.nz/papers/boxplots.pdf
#
# https://data.gov.ie/dataset/valentia-observatory-monthly-data/resource/16b3b81c-1ffe-4b2d-8495-50b1fcf4fa80
#
# https://www.wellbeingatschool.org.nz/information-sheet/understanding-and-interpreting-box-plots
#
# https://en.wikipedia.org/wiki/Violin_plot
#
# https://sites.google.com/site/davidsstatistics/home/notched-box-plots
#
# http://had.co.nz/stat645/project-03/boxplots.pdf
